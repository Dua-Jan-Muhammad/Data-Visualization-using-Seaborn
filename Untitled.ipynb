# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline 
#to display the plot in the notebook

# %%
Data = pd.read_csv('SurveyData.csv')
print(Data.info())
Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   gender                                 85 non-null     object
#  1   Current University Year                85 non-null     object
#  2   anxiety                                85 non-null     object
#  3   anxiety symptoms                       85 non-null     object
#  4   anxiety Type                           85 non-null     object
#  5   career path                            85 non-null     object
#  6   Stress Level                           85 non-null     int64
#  7   GPA                                    85 non-null     object
#  8   university Fee                         85 non-null     object
#  9   family responsibilities                85 non-null     object
# ...

# %%
# corr_matrix = Data.corr()['gender']
# corr_matrix


sb.countplot(data = Data, x = 'anxiety', hue = 'stressed future career?')
# Out:
# <Axes: xlabel='anxiety', ylabel='count'>

# %%
for col in Data.columns:
    print(col)
# Out:
# gender
# Current University Year
# anxiety
# anxiety symptoms
# anxiety Type
# career path
# Stress Level
# GPA
# university Fee
# family responsibilities
# job
# friendships
# feel accepted
# discriminated
# nature of the discrimination
# comparing achievements
# stressed future career?
# extracurricular activities
# support to manage your mental health
# assistance from faculty
# assistance from uni
# support mechanisms
# Your age
